# %% [markdown]
# CAPSTONE: The optimal Virtual Reality bar location in Ontario

# %% [markdown]
# 1 Libraries and functions needed

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage & standardscaler
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler


#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium  as fol# map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
def nearbyvenue_search(lats, lngs, query, limit=20, radius=3000 ):
    # function to find based on a query venues nearby for some coordinate using Foursquare search engine.
    res=[]
    CLIENT_ID = '5LTBU1OMDMGMGPW5AMTVSU5B1EPSYCFHZVNZGSJU5INIOIEI' # your Foursquare ID
    CLIENT_SECRET = 'VVKY5TYJJBFCJUZPM2KVN0J5MUSMFGXTQ01GRGY0I25VWWTN' # your Foursquare Secret
    VERSION = '20180605' # Foursquare API version

    base_url= 'https://api.foursquare.com/v2/venues/search?'
    
    for lat, lng in zip( lats, lngs):
        url= base_url + '&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&query={}&limit={}'.format(
                CLIENT_ID,
                CLIENT_SECRET,
                VERSION,
                lat,
                lng,
                radius,
                query,
                limit)
        try:
            result= requests.get(url).json()
        except:
            print('Error searching: {},{}. Assigning 0 venues.'.format(lat, lng))
            result= { 'response':{} }
        res.append(result)
    return res

def extract_results( results, amt=[], venues=[], unique_venues= [], specs= [] , excls= []):
    '''Extract/update from each json in the list of [results] the [amt] of venues and the [unique_venues]. 
    Optionally return only venues containing a string in the [specs] list and not one in the [exclude] list.
    Return a list with the number of venues in each result and a dataframe with the lat/lng/name of each unique venue'''

    for i, result in enumerate( results ):
        
        if len( amt ) < len( results ): 
            amt.append( 0 )
        
        # non-empty result
        if result['response'] != {}:
                
            # iterate through the venues in the response
            for venue in result['response']['venues']:

                # make a tuple of the lat/lng/name of each venue
                temp_venue= ( venue['location']['lat'], venue['location']['lng'], venue['name'] )

                # if the specifics list is nonempty check that at least one of the strings is in the venue name
                # if there are specifics and they aren't in the venue name move on to the next venue
                # similar process if a string in the inclusion list is present
                if ( specs != [] ) & ( np.array([spec.lower() in temp_venue[2].lower() for spec in specs] ).sum() == 0): 
                    continue
                if ( excls != [] ) & ( np.array([excl.lower() in temp_venue[2].lower() for excl in excls] ).sum() != 0): 
                    continue

                amt[i]+= 1 
                
                # if we haven't encountered this venue, add it to our unique venue list
                if not temp_venue in unique_venues: 
                    unique_venues+= [ temp_venue ]
                    
    return amt, unique_venues

def plot_points( lats, lngs , radii=[], colors=[], labels=[], opacities=[], toner=False,zoom=12, prev_map= None):
    '''Plot/add coordinates [lats/lngs] with optional [radii],[colors],[labels]. Optinally update a [prev_map].
    Return a map.'''
    
    pt_amt= len( lats )
    
    # check initial conditions    
    make_popups= lambda labels: [ fol.Popup( l, parse_html=True) for l in labels ] \
                                if len( labels ) == pt_amt \
                                else [None] * pt_amt
    check_radii= lambda radii: radii if len( radii ) == pt_amt else [1] * pt_amt
    check_colors= lambda colors: colors if len( colors ) == pt_amt else ['black'] * pt_amt
    check_opacities= lambda opacities: opacities if len( opacities ) == pt_amt else [1] * pt_amt
    
    popups= make_popups( labels )
    radii= check_radii( radii )
    colors= check_colors( colors )
    opacities= check_opacities( opacities )
    
    # if there was no previous map make a new one
    if prev_map == None:
        center= [ lats.mean(), lngs.mean() ]
        tiles= 'Stamen Toner' if toner else 'OpenStreetMap'
        prev_map= fol.Map( location=center, zoom_start=zoom, control_scale=True, tiles=tiles)
        
    for lat, lng, r, color, op, popup in zip(lats, lngs, radii, colors, opacities, popups):
        fol.Circle(
            location=[lat,lng],
            radius=r,
            color=color,
            popup= popup,
            fill=True,
            fill_color=color,
            fill_opacity=op
        ).add_to(prev_map)

    return prev_map

# %% [markdown]
# 2 get the data & clean

# %%
data= pd.read_excel('https://files.ontario.ca/opendata/sif_data_table_2015_2016_en.xlsx')

# %%
data.head()
# Out:
#   Board Number  Board Name              Board Type  School Number  \
# 0       B28010  Algoma DSB  Pub Dist Sch Brd (E/F)         902344
# 1       B28010  Algoma DSB  Pub Dist Sch Brd (E/F)          19186
# 2       B28010  Algoma DSB  Pub Dist Sch Brd (E/F)          67679
# 3       B28010  Algoma DSB  Pub Dist Sch Brd (E/F)          43362
# 4       B28010  Algoma DSB  Pub Dist Sch Brd (E/F)          54542
#
#                                     School Name School Type  \
# 0  Algoma Education Connection Secondary School      Public
# 1                     Anna McCrea Public School      Public
# 2                Arthur Henderson Public School      Public
# 3                  Ben R McMullin Public School      Public
# 4                     Blind River Public School      Public
#
#   School Special Condition Code School Level School Language Grade Range  \
# 0                   Alternative    Secondary         English        9-12
# 1                Not applicable   Elementary         English        JK-8
# 2                Not applicable   Elementary         English        JK-8
# 3                Not applicable   Elementary         English        JK-8
# 4                Not applicable   Elementary         English        JK-8
#
#   Building Suite P.O. Box               Street      Municipality  \
# 0            NaN      NaN  550 NORTHERN AVENUE  Sault Ste. Marie
# 1            NaN      NaN             250 Mark  Sault Ste. Marie
# 2            NaN      NaN          2 Henderson       Bruce Mines
# 3            NaN      NaN          24 Paradise  Sault Ste. Marie
# 4            NaN  Box 850             19 Hanes       Blind River
#
#                City Province Postal Code  Phone Number    Fax Number  \
# 0  Sault Ste. Marie  Ontario      P6B4J4           NaN           NaN
# 1   Sault Ste Marie  Ontario      P6A3M7  705-945-7106  705-945-7221
# 2       Bruce Mines  Ontario      P0R1C0  705-785-3483  705-785-3220
# 3   Sault Ste Marie  Ontario      P6B5K2  705-945-7108  705-945-7205
# 4       Blind River  Ontario      P0R1B0  705-356-7752  705-356-0271
#
#                                       School Website          Board Website  \
# 0             http://www.adsb.on.ca/content/schools/  http://www.adsb.on.ca
# 1                      http://annamccrea.adsb.on.ca/  http://www.adsb.on.ca
# 2  http://www.adsb.on.ca/content/schools/school_d...  http://www.adsb.on.ca
# 3  http://www.adsb.on.ca/content/schools/school_d...  http://www.adsb.on.ca
# 4  http://www.adsb.on.ca/content/schools/school_d...  http://www.adsb.on.ca
#
#    Enrolment  Latitude  Longitude  \
# 0      236.0  46.53477  -84.30772
# 1      168.0  46.50593  -84.28732
# 2      101.0  46.30183  -83.78020
# 3      189.0  46.52455  -84.29804
# 4      187.0  46.18454  -82.95760
#
#   Percentage of Students Whose First Language Is Not English  \
# 0                                                NaN
# 1                                                 SP
# 2                                                 SP
# 3                                                 SP
# 4                                                 SP
#
#   Percentage of Students Whose First Language Is Not French  \
# 0                                                100
# 1                                                100
# 2                                                100
# 3                                                100
# 4                                                100
#
#   Percentage of Students Who Are New to Canada from a Non-English Speaking Country  \
# 0                                                NaN
# 1                                                 SP
# 2                                                NaN
# 3                                                 SP
# 4                                                 SP
#
#   Percentage of Students Who Are New to Canada from a Non-French Speaking Country  \
# 0                                                NaN
# 1                                                 SP
# 2                                                NaN
# 3                                                 SP
# 4                                                 SP
#
#   Percentage of Students Receiving Special Education Services  \
# 0                                               18.6
# 1                                               15.5
# 2                                               11.9
# 3                                               13.8
# 4                                                 23
#
#   Percentage of Students Identified as Gifted  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                          SP
# 4                                         NaN
#
#   Percentage of Grade 3 Students Achieving the Provincial Standard in Reading  \
# 0                                                NaN
# 1                                               0.77
# 2                                               0.38
# 3                                               0.44
# 4                                                0.5
#
#    Change in Grade 3 Reading Achievement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Percentage of Grade 3 Students Achieving the Provincial Standard in Writing  \
# 0                                                NaN
# 1                                               0.58
# 2                                               0.31
# 3                                               0.38
# 4                                               0.36
#
#    Change in Grade 3 Writing Acheivement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Percentage of Grade 3 Students Achieving the Provincial Standard in Mathematics  \
# 0                                                NaN
# 1                                               0.81
# 2                                               0.46
# 3                                               0.44
# 4                                                0.5
#
#    Change in Grade 3 Mathematics Achievement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Percentage of Grade 6 Students Achieving the Provincial Standard in Reading  \
# 0                                                NaN
# 1                                                0.8
# 2                                                N/D
# 3                                               0.74
# 4                                               0.52
#
#    Change in Grade 6 Reading Achievement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Percentage of Grade 6 Students Achieving the Provincial Standard in Writing  \
# 0                                                NaN
# 1                                               0.67
# 2                                                N/D
# 3                                               0.65
# 4                                               0.65
#
#    Change in Grade 6 Writing Acheivement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Percentage of Grade 6 Students Achieving the Provincial Standard in Mathematics  \
# 0                                                NaN
# 1                                               0.53
# 2                                                N/D
# 3                                               0.22
# 4                                                0.3
#
#    Change in Grade 6 Mathematics Achievement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Percentage of Grade 9 Students Achieving the Provincial Standard in Academic Mathematics  \
# 0                                                N/D
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Change in Grade 9 Academic Mathematics Acheivement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Percentage of Grade 9 Students Achieving the Provincial Standard in Applied Mathematics  \
# 0                                                N/R
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Change in Grade 9 Applied Mathematics Achievement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Percentage of Students That Passed the Grade 10 OSSLT on Their First Attempt  \
# 0                                                N/R
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Change in Grade 10 OSSLT Literacy Achievement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Percentage of Children Who Live in Low-Income Households  \
# 0                                              33.88
# 1                                                8.1
# 2                                              13.42
# 3                                               27.9
# 4                                              22.36
#
#   Percentage of Students Whose Parents Have Some Unviersity Education  \
# 0                                                 SP
# 1                                              20.97
# 2                                                 SP
# 3                                              14.95
# 4                                               10.7
#
#    Percentage of JK-Grade 3 Classes With 20 Students or Fewer  \
# 0                                                NaN
# 1                                                1.0
# 2                                                0.0
# 3                                                1.0
# 4                                                1.0
#
#    Percentage of JK-Grade 3 Classes With 23 Students or Fewer Extract Date
# 0                                                NaN             Dec-04-17
# 1                                                1.0             Dec-04-17
# 2                                                1.0             Dec-04-17
# 3                                                1.0             Dec-04-17
# 4                                                1.0             Dec-04-17

# %%
# drop what seem to be keys as well as irrelevant/redundant columns
data.drop(['Board Number','Board Type','School Number', 'Province', 'Municipality','School Website','Board Website','Building Suite','P.O. Box'],axis=1,inplace=True)

# title case the city column for ease
data['City'] = data['City'].apply(lambda x: x.title())

print('The data has {} rows & {} cols.'.format(data.shape[0],data.shape[1]))

data.head(2)
# Out:
# The data has 4934 rows & 44 cols.
#    Board Name                                   School Name School Type  \
# 0  Algoma DSB  Algoma Education Connection Secondary School      Public
# 1  Algoma DSB                     Anna McCrea Public School      Public
#
#   School Special Condition Code School Level School Language Grade Range  \
# 0                   Alternative    Secondary         English        9-12
# 1                Not applicable   Elementary         English        JK-8
#
#                 Street              City Postal Code  Phone Number  \
# 0  550 NORTHERN AVENUE  Sault Ste. Marie      P6B4J4           NaN
# 1             250 Mark   Sault Ste Marie      P6A3M7  705-945-7106
#
#      Fax Number  Enrolment  Latitude  Longitude  \
# 0           NaN      236.0  46.53477  -84.30772
# 1  705-945-7221      168.0  46.50593  -84.28732
#
#   Percentage of Students Whose First Language Is Not English  \
# 0                                                NaN
# 1                                                 SP
#
#   Percentage of Students Whose First Language Is Not French  \
# 0                                                100
# 1                                                100
#
#   Percentage of Students Who Are New to Canada from a Non-English Speaking Country  \
# 0                                                NaN
# 1                                                 SP
#
#   Percentage of Students Who Are New to Canada from a Non-French Speaking Country  \
# 0                                                NaN
# 1                                                 SP
#
#   Percentage of Students Receiving Special Education Services  \
# 0                                               18.6
# 1                                               15.5
#
#   Percentage of Students Identified as Gifted  \
# 0                                         NaN
# 1                                         NaN
#
#   Percentage of Grade 3 Students Achieving the Provincial Standard in Reading  \
# 0                                                NaN
# 1                                               0.77
#
#    Change in Grade 3 Reading Achievement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
#
#   Percentage of Grade 3 Students Achieving the Provincial Standard in Writing  \
# 0                                                NaN
# 1                                               0.58
#
#    Change in Grade 3 Writing Acheivement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
#
#   Percentage of Grade 3 Students Achieving the Provincial Standard in Mathematics  \
# 0                                                NaN
# 1                                               0.81
#
#    Change in Grade 3 Mathematics Achievement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
#
#   Percentage of Grade 6 Students Achieving the Provincial Standard in Reading  \
# 0                                                NaN
# 1                                                0.8
#
#    Change in Grade 6 Reading Achievement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
#
#   Percentage of Grade 6 Students Achieving the Provincial Standard in Writing  \
# 0                                                NaN
# 1                                               0.67
#
#    Change in Grade 6 Writing Acheivement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
#
#   Percentage of Grade 6 Students Achieving the Provincial Standard in Mathematics  \
# 0                                                NaN
# 1                                               0.53
#
#    Change in Grade 6 Mathematics Achievement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
#
#   Percentage of Grade 9 Students Achieving the Provincial Standard in Academic Mathematics  \
# 0                                                N/D
# 1                                                NaN
#
#    Change in Grade 9 Academic Mathematics Acheivement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
#
#   Percentage of Grade 9 Students Achieving the Provincial Standard in Applied Mathematics  \
# 0                                                N/R
# 1                                                NaN
#
#    Change in Grade 9 Applied Mathematics Achievement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
#
#   Percentage of Students That Passed the Grade 10 OSSLT on Their First Attempt  \
# 0                                                N/R
# 1                                                NaN
#
#    Change in Grade 10 OSSLT Literacy Achievement Over Three Years  \
# 0                                                NaN
# 1                                                NaN
#
#   Percentage of Children Who Live in Low-Income Households  \
# 0                                              33.88
# 1                                                8.1
#
#   Percentage of Students Whose Parents Have Some Unviersity Education  \
# 0                                                 SP
# 1                                              20.97
#
#    Percentage of JK-Grade 3 Classes With 20 Students or Fewer  \
# 0                                                NaN
# 1                                                1.0
#
#    Percentage of JK-Grade 3 Classes With 23 Students or Fewer Extract Date
# 0                                                NaN             Dec-04-17
# 1                                                1.0             Dec-04-17

# %%
# extract only the columns we want
columns= ['School Name','Enrolment','Latitude','Longitude','City','Percentage of Children Who Live in Low-Income Households','Percentage of Students Whose Parents Have Some Unviersity Education']
school_data= data[columns].copy()

# %%
school_data.head(5)
# Out:
#                                     School Name  Enrolment  Latitude  \
# 0  Algoma Education Connection Secondary School      236.0  46.53477
# 1                     Anna McCrea Public School      168.0  46.50593
# 2                Arthur Henderson Public School      101.0  46.30183
# 3                  Ben R McMullin Public School      189.0  46.52455
# 4                     Blind River Public School      187.0  46.18454
#
#    Longitude              City  \
# 0  -84.30772  Sault Ste. Marie
# 1  -84.28732   Sault Ste Marie
# 2  -83.78020       Bruce Mines
# 3  -84.29804   Sault Ste Marie
# 4  -82.95760       Blind River
#
#   Percentage of Children Who Live in Low-Income Households  \
# 0                                              33.88
# 1                                                8.1
# 2                                              13.42
# 3                                               27.9
# 4                                              22.36
#
#   Percentage of Students Whose Parents Have Some Unviersity Education
# 0                                                 SP
# 1                                              20.97
# 2                                                 SP
# 3                                              14.95
# 4                                               10.7

# %%
# change the column names to make them easier to work with
school_data.columns= ['school','enrol','lat','lng','city','pct_low_income', 'pct_uni_parents']

# drop all entries with null in any of the specified columns
school_data.dropna(subset= ['school','enrol','lat','lng','city'], inplace=True)

school_data.head(5)
# Out:
#                                          school  enrol       lat       lng  \
# 0  Algoma Education Connection Secondary School  236.0  46.53477 -84.30772
# 1                     Anna McCrea Public School  168.0  46.50593 -84.28732
# 2                Arthur Henderson Public School  101.0  46.30183 -83.78020
# 3                  Ben R McMullin Public School  189.0  46.52455 -84.29804
# 4                     Blind River Public School  187.0  46.18454 -82.95760
#
#                city pct_low_income pct_uni_parents
# 0  Sault Ste. Marie          33.88              SP
# 1   Sault Ste Marie            8.1           20.97
# 2       Bruce Mines          13.42              SP
# 3   Sault Ste Marie           27.9           14.95
# 4       Blind River          22.36            10.7

# %%
# Replace null values in the numerical columns with the average values
for col in school_data:
    if not col in ['school', 'enrol', 'lat', 'lng' ,'city']:
        avg= 0
        num_entries= 0
        for val in school_data[col].values:
            if (not val in ['SP','N/R','N/D']) & (val == val):
                avg+= val
                num_entries+= 1
        avg= avg / num_entries
        school_data[col].replace( ['SP','N/R','N/D', np.nan], avg, inplace=True )


school_data.head(2)
# Out:
#                                          school  enrol       lat       lng  \
# 0  Algoma Education Connection Secondary School  236.0  46.53477 -84.30772
# 1                     Anna McCrea Public School  168.0  46.50593 -84.28732
#
#                city  pct_low_income  pct_uni_parents
# 0  Sault Ste. Marie           33.88        24.362596
# 1   Sault Ste Marie            8.10        20.970000

# %%
# double-check if all data types are numeric
school_data.dtypes
# Out:
# school              object
# enrol              float64
# lat                float64
# lng                float64
# city                object
# pct_low_income     float64
# pct_uni_parents    float64
# dtype: object

# %%
school_data.shape
# Out:
# (4809, 7)

# %%
# deep-dive on North York
North_York_data= school_data[ school_data.city == 'North York' ].copy()
North_York_data.reset_index(drop=True, inplace=True)
North_York_data.head(2)
North_York_data.shape
# Out:
# (123, 7)

# %%
# search via the foursquare engine nearby virtual reality bar/gaming centers

amt= []
unique_gaming_center= []

print('Working.. 1/2')
results1= nearbyvenue_search(North_York_data.lat, North_York_data.lng, query='virtual')
amt, unique_gaming_center= extract_results(results1,amt=amt, unique_venues=unique_gaming_center,excls= 'Virtual School')

print('Working.. 2/2')
results2= nearbyvenue_search(North_York_data.lat, North_York_data.lng, query='gaming')
amt, unique_gaming_center= extract_results(results2, amt=amt, unique_venues=unique_gaming_center)

# make a column for the number of gaming centers/virtual reality bars near each school
North_York_data['gaming_centers']= amt

# this is a measure of how good the school is based on how many students are in it and the number of VR bars/ gaming centers near it
North_York_data['enrol_gaming_center_ratio']= North_York_data.enrol / (North_York_data.gaming_centers + 1 )

print('Results collected.')
North_York_data.head(2)
# Out:
# Working.. 1/2
# Working.. 2/2
# Results collected.
#                             school  enrol       lat       lng        city  \
# 0  École élémentaire Étienne-Brûlé  163.0  43.75241 -79.37110  North York
# 1  École élémentaire Jeanne-Lajoie  473.0  43.73463 -79.32135  North York
#
#    pct_low_income  pct_uni_parents  gaming_centers  enrol_gaming_center_ratio
# 0           26.63            29.46               2                  54.333333
# 1           30.43            32.33               0                 473.000000

# %%
#make a dataframe with the information for each unique VR bar/ gaming center found
unique_gaming_center_df= pd.DataFrame.from_records(unique_gaming_center, columns=['lat','lng','name'])
unique_gaming_center_df
# Out:
#          lat        lng                                      name
# 0  43.762815 -79.406110  Alcohol and Gaming Commission of Ontario
# 1  43.748286 -79.407303                            WorldGaming HQ
# 2  43.730054 -79.469507                              Legit Gaming
# 3  43.746834 -79.408644            Ontario Lottery & Gaming (OLG)
# 4  43.774389 -79.440212      Card Masters Gaming and Collectibles

# %%
gc_amt= unique_gaming_center_df.shape[0]

# make yellow circles signifying the effective radius of each gaming center
area_map= plot_points( unique_gaming_center_df.lat, 
                         unique_gaming_center_df.lng,
                         [3000] * gc_amt,
                         ['yellow'] * gc_amt,
                         opacities= [0.1] * gc_amt )

# add the gaming centers to the map
gc_map= plot_points( unique_gaming_center_df.lat, 
                         unique_gaming_center_df.lng,
                         [100] * gc_amt,
                         ['red'] * gc_amt, 
                         unique_gaming_center_df.name, 
                         prev_map=area_map )


# add the schools to the map
sch_amt= North_York_data.shape[0]
labels= [ name + ' : {} gaming center'.format(gc) for name, gc in zip( North_York_data.school, North_York_data.gaming_centers ) ]

full_map= plot_points( North_York_data.lat, 
                         North_York_data.lng,
                         [80] * sch_amt,
                         ['blue'] * sch_amt, 
                         labels,
                         North_York_data.gaming_centers / North_York_data.gaming_centers.max(),
                         prev_map=gc_map )

full_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# df for kMeans algorithm
cols= ['school', 'lat', 'lng', 'city','pct_uni_parents']
kmeans_tempdf= North_York_data.drop(cols, axis=1)
# ensure there are no null values
kmeans_tempdf.head(2)
# Out:
#    enrol  pct_low_income  gaming_centers  enrol_gaming_center_ratio
# 0  163.0           26.63               2                  54.333333
# 1  473.0           30.43               0                 473.000000

# %%
kmeans_tempdf.head(20         )
# Out:
#     enrol  pct_low_income  gaming_centers  enrol_gaming_center_ratio
# 0   163.0           26.63               2                  54.333333
# 1   473.0           30.43               0                 473.000000
# 2   181.0           27.63               1                  90.500000
# 3   315.0           30.16               2                 105.000000
# 4   183.0           31.11               1                  91.500000
# 5   269.0           23.89               0                 269.000000
# 6   729.0           30.07               0                 729.000000
# 7   584.0           16.02               5                  97.333333
# 8   300.0           31.06               1                 150.000000
# 9   104.0           22.86               1                  52.000000
# 10  336.0           17.61               0                 336.000000
# 11  333.0            9.73               3                  83.250000
# 12  140.0           20.46               4                  28.000000
# 13  291.0           38.83               4                  58.200000
# 14   71.0           24.18               2                  23.666667
# 15  128.0           34.86               1                  64.000000
# 16  411.0           25.68               3                 102.750000
# 17  426.0           30.47               1                 213.000000
# 18  217.0           30.37               0                 217.000000
# 19  181.0           27.46               1                  90.500000

# %%
# fit our data to emulate a standard normal distribution to make sure all factors are equal
X= np.nan_to_num( kmeans_tempdf.values )

#kmeans_tempdf.dtypes
X= StandardScaler().fit_transform(X)
print(X[:5])
print('Data Standardized.')
# Out:
# [[-0.88718571 -0.07991524  0.70429827 -1.04164612]
#  [ 0.4383782   0.4440346  -0.72758085  1.10571043]
#  [-0.81021748  0.0579663  -0.01164129 -0.85614598]
#  [-0.23723179  0.40680659  0.70429827 -0.78177495]
#  [-0.80166546  0.53779405 -0.01164129 -0.85101694]]
# Data Standardized.

# %%
clusters= 6

# run k-means on the data separated
kmeans= KMeans(init='k-means++', n_clusters=clusters, n_init= 12)
kmeans.fit(X)
print('Model fit with data.')
# Out:
# Model fit with data.

# %%
# make a column for the clusters given to each school
North_York_data['cluster']= kmeans.labels_
North_York_data[['school','cluster']].head(100)
# Out:
#                                          school  cluster
# 0               École élémentaire Étienne-Brûlé        3
# 1               École élémentaire Jeanne-Lajoie        0
# 2            École élémentaire Mathieu-da-Costa        3
# 3                École secondaire Étienne-Brûlé        3
# 4               Blessed Trinity Catholic School        3
# 5                      St Agnes Catholic School        4
# 6               St Jane Frances Catholic School        0
# 7                     St Robert Catholic School        1
# 8                        Amesbury Middle School        3
# 9                        Ancaster Public School        3
# 10                     Arbor Glen Public School        4
# 11                 Armour Heights Public School        1
# 12       Avondale Alternative Elementary School        1
# 13                       Avondale Public School        3
# 14        Avondale Secondary Alternative School        3
# 15                       Baycrest Public School        3
# 16                        Bayview Middle School        1
# 17               Beverley Heights Middle School        2
# 18                     Blacksmith Public School        2
# 19                        Blaydon Public School        3
# 20                          Brian Public School        4
# 21                     Broadlands Public School        0
# 22                     Brookhaven Public School        2
# 23                      Brookview Middle School        2
# 24            C W Jefferys Collegiate Institute        0
# 25                         Calico Public School        3
# 26                        Cameron Public School        1
# 27                      Cassandra Public School        4
# 28                      Chalkfarm Public School        2
# 29                 Charles H Best Middle School        3
# 30                       Cherokee Public School        3
# 31                      Churchill Public School        1
# 32            Claude Watson School for the Arts        1
# 33                      Cliffwood Public School        4
# 34                     Cresthaven Public School        2
# 35                  Cummer Valley Middle School        4
# 36                     Dallington Public School        0
# 37                       Daystrom Public School        0
# 38                      Derrydown Public School        0
# 39               Don Mills Collegiate Institute        0
# 40                      Don Mills Middle School        4
# 41                        Donview Middle School        4
# 42                      Downsview Public School        3
# 43                   Downsview Secondary School        2
# 44                      Drewry Secondary School        3
# 45                      Driftwood Public School        2
# 46  Dublin Heights Elementary and Middle School        1
# 47                        Dunlace Public School        1
# 48                   Earl Haig Secondary School        5
# 49                           Elia Middle School        2
# 50                        Elkhorn Public School        1
# 51                   Emery Collegiate Institute        0
# 52                         Ernest Public School        4
# 53         Faywood Arts-Based Curriculum School        1
# 54                        Fenside Public School        4
# 55                       Firgrove Public School        2
# 56             Fisherville Senior Public School        3
# 57                     Flemington Public School        2
# 58                   Forest Manor Public School        0
# 59                        Gateway Public School        0
# 60                George Anderson Public School        3
# 61                       George S Henry Academy        0
# 62              Georges Vanier Secondary School        0
# 63                      Glen Park Public School        4
# 64                        Gosford Public School        2
# 65                      Gracedale Public School        0
# 66                     Gracefield Public School        3
# 67                      Greenland Public School        4
# 68                     Gulfstream Public School        0
# 69                       Harrison Public School        1
# 70                       Highland Middle School        4
# 71                       Highview Public School        3
# 72                      Hollywood Public School        1
# 73                  Humber Summit Middle School        0
# 74                          Joyce Public School        3
# 75                      Kingslake Public School        4
# 76                      Lamberton Public School        2
# 77               Lawrence Heights Middle School        2
# 78    Ledbury Park Elementary and Middle School        1
# 79                         Lescon Public School        4
# 80                        Lillian Public School        2
# 81                     Maple Leaf Public School        2
# 82                          McKee Public School        1
# 83                   Milne Valley Middle School        0
# 84                  Norman Ingram Public School        4
# 85     North West Year Round Alternative Centre        3
# 86                   Oakdale Park Middle School        2
# 87                       O'Connor Public School        2
# 88                           Owen Public School        1
# 89                      Park Lane Public School        3
# 90                     Pelmo Park Public School        2
# 91                 Pierre Laporte Middle School        3
# 92                        Pineway Public School        2
# 93                       Pleasant Public School        4
# 94             Pleasant View Junior High School        4
# 95               Portage Trail Community School        0
# 96        R J Lang Elementary and Middle School        4
# 97                      Ranchdale Public School        4
# 98      Rene Gordon Health and Wellness Academy        4
# 99                      Rippleton Public School        4

# %%
North_York_data[['school','cluster']].head(100)
# Out:
#                                          school  cluster
# 0               École élémentaire Étienne-Brûlé        3
# 1               École élémentaire Jeanne-Lajoie        0
# 2            École élémentaire Mathieu-da-Costa        3
# 3                École secondaire Étienne-Brûlé        3
# 4               Blessed Trinity Catholic School        3
# 5                      St Agnes Catholic School        4
# 6               St Jane Frances Catholic School        0
# 7                     St Robert Catholic School        1
# 8                        Amesbury Middle School        3
# 9                        Ancaster Public School        3
# 10                     Arbor Glen Public School        4
# 11                 Armour Heights Public School        1
# 12       Avondale Alternative Elementary School        1
# 13                       Avondale Public School        3
# 14        Avondale Secondary Alternative School        3
# 15                       Baycrest Public School        3
# 16                        Bayview Middle School        1
# 17               Beverley Heights Middle School        2
# 18                     Blacksmith Public School        2
# 19                        Blaydon Public School        3
# 20                          Brian Public School        4
# 21                     Broadlands Public School        0
# 22                     Brookhaven Public School        2
# 23                      Brookview Middle School        2
# 24            C W Jefferys Collegiate Institute        0
# 25                         Calico Public School        3
# 26                        Cameron Public School        1
# 27                      Cassandra Public School        4
# 28                      Chalkfarm Public School        2
# 29                 Charles H Best Middle School        3
# 30                       Cherokee Public School        3
# 31                      Churchill Public School        1
# 32            Claude Watson School for the Arts        1
# 33                      Cliffwood Public School        4
# 34                     Cresthaven Public School        2
# 35                  Cummer Valley Middle School        4
# 36                     Dallington Public School        0
# 37                       Daystrom Public School        0
# 38                      Derrydown Public School        0
# 39               Don Mills Collegiate Institute        0
# 40                      Don Mills Middle School        4
# 41                        Donview Middle School        4
# 42                      Downsview Public School        3
# 43                   Downsview Secondary School        2
# 44                      Drewry Secondary School        3
# 45                      Driftwood Public School        2
# 46  Dublin Heights Elementary and Middle School        1
# 47                        Dunlace Public School        1
# 48                   Earl Haig Secondary School        5
# 49                           Elia Middle School        2
# 50                        Elkhorn Public School        1
# 51                   Emery Collegiate Institute        0
# 52                         Ernest Public School        4
# 53         Faywood Arts-Based Curriculum School        1
# 54                        Fenside Public School        4
# 55                       Firgrove Public School        2
# 56             Fisherville Senior Public School        3
# 57                     Flemington Public School        2
# 58                   Forest Manor Public School        0
# 59                        Gateway Public School        0
# 60                George Anderson Public School        3
# 61                       George S Henry Academy        0
# 62              Georges Vanier Secondary School        0
# 63                      Glen Park Public School        4
# 64                        Gosford Public School        2
# 65                      Gracedale Public School        0
# 66                     Gracefield Public School        3
# 67                      Greenland Public School        4
# 68                     Gulfstream Public School        0
# 69                       Harrison Public School        1
# 70                       Highland Middle School        4
# 71                       Highview Public School        3
# 72                      Hollywood Public School        1
# 73                  Humber Summit Middle School        0
# 74                          Joyce Public School        3
# 75                      Kingslake Public School        4
# 76                      Lamberton Public School        2
# 77               Lawrence Heights Middle School        2
# 78    Ledbury Park Elementary and Middle School        1
# 79                         Lescon Public School        4
# 80                        Lillian Public School        2
# 81                     Maple Leaf Public School        2
# 82                          McKee Public School        1
# 83                   Milne Valley Middle School        0
# 84                  Norman Ingram Public School        4
# 85     North West Year Round Alternative Centre        3
# 86                   Oakdale Park Middle School        2
# 87                       O'Connor Public School        2
# 88                           Owen Public School        1
# 89                      Park Lane Public School        3
# 90                     Pelmo Park Public School        2
# 91                 Pierre Laporte Middle School        3
# 92                        Pineway Public School        2
# 93                       Pleasant Public School        4
# 94             Pleasant View Junior High School        4
# 95               Portage Trail Community School        0
# 96        R J Lang Elementary and Middle School        4
# 97                      Ranchdale Public School        4
# 98      Rene Gordon Health and Wellness Academy        4
# 99                      Rippleton Public School        4

# %%
color_map= [ 'red','blue','orange','black','lime','green','pink','purple','brown' ]

# show the number of schools in each cluster as well as the mean ratio for each 
view= North_York_data.groupby('cluster').mean().reset_index()
view['color']= view.cluster.apply( lambda c: color_map[c].title() )
view['count'] = North_York_data.cluster.value_counts(sort=False)

cols= view.columns.tolist()
cols= cols[-2:] + [cols[-3]] + [cols[1]] + cols[4:-3]
view= view[cols]

view.columns= [ s.replace('_', ' ').title() for s in view.columns ]
view.set_index('Color', inplace=True)
view.index.name= None
view.sort_values('Enrol Gaming Center Ratio', ascending=False ).apply( lambda x: round(x, 2), axis=1)
# Out:
#         Count  Enrol Gaming Center Ratio    Enrol  Pct Low Income  \
# Red      18.0                     621.28   621.28           29.86
# Green     1.0                     407.20  2036.00           32.71
# Orange   26.0                     285.31   326.88           35.15
# Lime     29.0                     269.67   317.03           24.42
# Black    28.0                     101.64   201.32           27.26
# Blue     21.0                      94.68   429.52           18.64
#
#         Pct Uni Parents  Gaming Centers
# Red               25.02            0.00
# Green             23.60            4.00
# Orange            15.75            0.23
# Lime              41.11            0.21
# Black             21.81            1.21
# Blue              43.43            3.57

# %%
avgs= North_York_data.enrol_gaming_center_ratio
sch_amt= North_York_data.shape[0]
labels= [ name + ' : {} naive-expected students'.format( ratio ) for name, ratio in zip( North_York_data.school, avgs.apply(int) ) ]
color_map= [ 'red','blue','orange','black','lime','green','deeppink','purple','brown' ]

full_map= plot_points( North_York_data.lat, 
                         North_York_data.lng,
                         50 + 200*(( avgs - avgs.min() ) / (avgs.max() - avgs.min() )),
                         [ color_map[ cluster ] for cluster in North_York_data.cluster ], 
                         labels,
                         [0.5] * sch_amt )#, toner=True)

full_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
